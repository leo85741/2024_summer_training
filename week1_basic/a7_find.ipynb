# %%
import time
from pymongo import MongoClient
from pymongo import errors


# MongoDB連接設定
uri = "mongodb://training:Bkmsz3024@192.168.31.89:30241/?authSource=2024_training&authMechanism=SCRAM-SHA-1"

try:
    client = MongoClient(uri)
    
    db = client['2024_training'] #client_db
    collection = db['youqi'] # db_collection
    
    for i in collection.find({},{}):
        print(i)
        print("")

except errors.ConnectionFailure as err:
    print(err)
# Out:
# {'_id': ObjectId('668f4d81919243eeb66bce9c'), 'name': '李雪倫', 'star': '4 顆星', 'comment_time': '3 週前', 'comment': '點了兩份無骨，青花椒跟醬油口味都好吃，不過無骨份量看起來較少。下次應該還是會選擇有骨的。', 'store_comment': '無'}
#
# {'_id': ObjectId('668f4d81919243eeb66bce9d'), 'name': 'Ho Jin H', 'star': '5 顆星', 'comment_time': '2 週前', 'comment': '網路訂餐，餐點正確無誤。\n價格訂位適中，對得起食物品質。', 'store_comment': '無'}
#
# {'_id': ObjectId('668f4d81919243eeb66bce9e'), 'name': 'Mercy', 'star': '5 顆星', 'comment_time': '10 個月前', 'comment': '2023/08/12\n因為聽同事推薦，所以決定電話預訂嚐鮮\n點了兩份半半回家跟家人分享 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bce9f'), 'name': '汪大升', 'star': '5 顆星', 'comment_time': '8 個月前', 'comment': '懶人包：原味及洋釀口味還不錯；起司口味偏甜；點心類的QQ球跟薯條一般。\n\n完整版：公司提供每人100元當下午茶，本來要點NENE韓式炸雞，但因為在改裝所以改成了起家雞。 …', 'store_comment': '感謝您的回饋！\n我們會加強不足的地方並在未來更好的服務您。\n謝謝貴公司的支持購買喔❤️'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcea0'), 'name': '王寶燦', 'star': '5 顆星', 'comment_time': '7 個月前', 'comment': '中午前台員工態度蠻好的\n炸雞建議現場現吃最好的狀態（可惜沒內用）\n好吃', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~❤️'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcea1'), 'name': 'Finn CJ', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '點了黃金起司半半口味的炸雞，付一包醃蘿蔔，加購30元的薯條，還有飯，跟一小杯辣味洋釀醬。\n起司口味的炸雞沒有起司的味道，吃起來甜甜的，吃到後面有點卡痰，原味的炸雞皮不是很脆，薯條一般般（付一包番茄醬），不過⋯很合我的胃口！我很喜歡！雞肉很嫩！這隻雞死的很有價值。 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcea2'), 'name': '紀建霆', 'star': '2 顆星', 'comment_time': '2 天前', 'comment': '22：00打烊\n21：30到現場卻說已經關爐火了\n這樣就不要寫22：00打烊 …', 'store_comment': '無'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcea3'), 'name': 'Ling', 'star': '5 顆星', 'comment_time': '11 個月前', 'comment': '服務人員，親切有禮，詢問餐點差異，也是很有耐心講解。\n\n外帶 ：半/洋釀炸雞  。 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcea4'), 'name': 'Chloe Yang', 'star': '3 顆星', 'comment_time': '1 個月前', 'comment': '多年前在台中吃過起家雞，驚喜發現高雄也有連鎖店，5/23晚上八點多進去的時候櫃檯的女服務生好厭世，不知道是職業倦怠還是怎樣，「妳要點餐嗎？」不然我來貴店是要做什麼…..我說我要看一下卻拿起手機在旁邊滑，對於客人的回答也是隨便帶過，不積極不友善真的會讓客人勸退。員工訓練再加油吧⋯⋯⋯⋯', 'store_comment': '很抱歉讓您有不佳的消費經驗，感謝您的回饋。\n針對您提出的問題我們加強改進。\n我們會再加強員工的訓練並努力做到最好！'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcea5'), 'name': '寶礦麗發哥', 'star': '5 顆星', 'comment_time': '8 個月前', 'comment': '今天外帶2份全雞餐 肉質很嫩又多汁 醬汁很韓國 值得現場等候', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcea6'), 'name': '豆腐', 'star': '5 顆星', 'comment_time': '8 個月前', 'comment': '第一次購買因為最近聯名活動套餐，想說順便買來吃吃看，結果還不錯。\n炸雞鮮嫩多汁不柴，我吃的口味是頂級洋釀搭配蘿蔔（套餐附的）非常讚👍👍\n地瓜QQ球和薯條也不錯但要熱熱吃，不要放太久。\n價格偏高建議多人一起吃\U0001f97a\U0001f97a\U0001f97a …', 'store_comment': '感謝您對本次聯名活動的喜愛及參與！\n歡迎再度光臨，要繼續支持起家雞唷❤️'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcea7'), 'name': 'Moe Fu', 'star': '4 顆星', 'comment_time': '1 年前', 'comment': '雞翅很好吃，肉質有脆脆的口感，和鮮嫩，但炸年糕太辣，個人感覺不那麼辣的話，應該比較好吃😄 …', 'store_comment': '無'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcea8'), 'name': 'Ingrid Ho', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '很適合獎勵自己的美味，多種口味可以選擇，太久沒吃的時候都會充滿懷念；\n\n可以事先電話預約取餐，很方便，店面明亮乾淨，值得推薦。', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcea9'), 'name': '慕少奇', 'star': '4 顆星', 'comment_time': '1 年前', 'comment': '今天去外帶 服務人員親切 點了招牌洋釀 好吃 辣炒年糕也很讚', 'store_comment': '感謝您的好評，歡迎再度光臨唷！\n我們會努力達到五顆星的！'}
#
# {'_id': ObjectId('668f4d81919243eeb66bceaa'), 'name': '林慧惠', 'star': '4 顆星', 'comment_time': '1 年前', 'comment': '很好吃！💕💕雞肉一點都不材香氣十足，可惜的一點是點半半一定要原味不能兩樣都是自己想吃的味道，但是原味炸雞也是很好吃！👍👍😋喜歡韓式炸雞的朋友要去試試！ …', 'store_comment': '感謝您的好評，歡迎再度光臨唷！\n我們會努力達到五顆星的！'}
#
# {'_id': ObjectId('668f4d81919243eeb66bceab'), 'name': 'DING SHU', 'star': '5 顆星', 'comment_time': '1 個月前', 'comment': '好吃出餐快 希望價格能更友善 不然太多國外來的同性質產品很容易被台灣低價產品比過', 'store_comment': '無'}
#
# {'_id': ObjectId('668f4d81919243eeb66bceac'), 'name': 'Ping Hung Yeh', 'star': '5 顆星', 'comment_time': '4 個月前', 'comment': '還不錯吃，價格不算便宜，吃多了容易膩！', 'store_comment': '感謝您的回饋！\n我們會加強不足的地方並在未來更好的服務您。\n期待您再次蒞臨❤️❤️❤️'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcead'), 'name': 'Iris', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '服務人員很親切\n原味基本上真的沒有什麼調味，整體偏單調，配著蘿蔔吃好一點\n招牌洋釀醬很好吃～個人比較推招牌洋釀', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bceae'), 'name': '亞紀', 'star': '3 顆星', 'comment_time': '1 年前', 'comment': '餐點準時服務人員親切。\n原味炸雞不夠酥，不柴但也沒有流汁，肉本身味道不足，感覺沒有醃過，起司口味沒有起司味道，被洋釀基底的醬味道蓋過去了。\n另外活動30元加購的薯條，份量尚可但很明顯與菜單寫的帶皮脆薯不同，既不是帶皮也沒有脆，沒有調味也沒有馬鈴薯香氣，如果是用原價95元購買的話非常不值得。', 'store_comment': '感謝您的好評，歡迎再度光臨唷！\n我們會努力達到五顆星的！'}
#
# {'_id': ObjectId('668f4d81919243eeb66bceaf'), 'name': '東', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '買了青蔥炸雞非常好吃😋，味道很道地\n炸雞淋上青蔥醬更有不一樣的風味\n下次會再回來回購 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bceb0'), 'name': 'Yun liao', 'star': '4 顆星', 'comment_time': '1 個月前', 'comment': '炸雞不錯，對得起這價格，如果會員禮能立刻使用就好了！', 'store_comment': '非常感謝您對起家雞的喜愛！\n小編會把您寶貴的意見提供給公司參考，\n我們會努力達到5顆星，期待您再次蒞臨❤️'}
#
# {'_id': ObjectId('668f4d81919243eeb66bceb1'), 'name': '童俊瑋', 'star': '1 顆星', 'comment_time': '6 個月前', 'comment': '半半只能選一種口味，加購的醬料裡面沒有松露芥末….要加購別的口味不行，一定要搭配原味口味的，希望能多多改善～', 'store_comment': '很抱歉讓您有不佳的消費體驗，也很感謝您的回饋🙇\u200d♀️🙇\u200d♂️\n『半半炸雞』是一隻雞分成兩種口味，一邊口味固定經典原味，另一邊可以自己做搭配。 … 全文'}
#
# {'_id': ObjectId('668f4d81919243eeb66bceb2'), 'name': 'Ray H', 'star': '5 顆星', 'comment_time': '4 個月前', 'comment': '真的非常好吃，且份量也超出預期的多，是目前吃過最好吃的韓式炸雞', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~\n期待您再次蒞臨❤️❤️❤️'}
#
# {'_id': ObjectId('668f4d81919243eeb66bceb3'), 'name': 'OO O', 'star': '5 顆星', 'comment_time': '2 個月前', 'comment': '中性店員很熱心，會主動跟客人介紹餐點\n服務態度很好 餐點好吃 👍 …', 'store_comment': '感謝您的喜愛！ 要繼續支持起家雞唷~ 期待您再次蒞臨❤️❤️❤️'}
#
# {'_id': ObjectId('668f4d81919243eeb66bceb4'), 'name': '黃昱傑', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '老大推薦的黑辣波真的讚讚\n外帶回家香整路\n打開吃起來\n沒有讓我失望啦', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bceb5'), 'name': 'peichi Kao', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '吃的是無骨原味口味，熱熱吃超好吃～～～醃蘿蔔也很脆很好吃！', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bceb6'), 'name': 'Ivy Chang', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '叫外送～\n阿嬤很喜歡～好吃到 隔兩天還說要叫來吃🤣 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bceb7'), 'name': '古月小姐', 'star': '4 顆星', 'comment_time': '1 年前', 'comment': '加了柴魚真的非常對味\n但對我而言\n真的太辣了😂\n適合吃大辣的人 …', 'store_comment': '感謝您的好評，歡迎再度光臨唷！\n我們會努力達到五顆星的！'}
#
# {'_id': ObjectId('668f4d81919243eeb66bceb8'), 'name': 'HsiuChi Hsu.', 'star': '5 顆星', 'comment_time': '6 個月前', 'comment': '跨年夜很多訂餐，現場取餐人很多，店員處理速度很快，服務也沒有不耐煩，沒有因為爆單而延遲太久取餐', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~❤️'}
#
# {'_id': ObjectId('668f4d81919243eeb66bceb9'), 'name': '李芯榆', 'star': '5 顆星', 'comment_time': '6 個月前', 'comment': '肉質真的好好吃好喜歡起家雞的炸雞 超喜歡婕瑜的服務態度 店裡的氛圍也都很融洽很舒服😍一百分😍 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~❤️'}
#
# {'_id': ObjectId('668f4d81919243eeb66bceba'), 'name': 'Erin Liao', 'star': '5 顆星', 'comment_time': '5 個月前', 'comment': '經過臨時決定買了吃，等15-20分鐘，櫃檯人員態度很好，餐點也很好吃。', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~\n期待您再次蒞臨❤️❤️❤️'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcebb'), 'name': 'Yiwei Huang', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '點了半半的頂級洋釀！兩種口味交換吃～原味就已經很香了，洋釀又是另一種濃郁滋味都很好吃👍外帶到家之後還是一樣美味～肉本身就醃得很好吃～配菜的醃蘿蔔有夠脆的也好喜歡💕我覺得炸年糕(但是好辣)跟飯糰(也會辣T_T)必點～怕辣的我配水喝也要吃的程度！ …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcebc'), 'name': 'JJ Yang', 'star': '5 顆星', 'comment_time': '10 個月前', 'comment': '餐點好吃\n然後發生一個小插曲\n我訂餐時間是5：30到6：00 …', 'store_comment': '感謝您的喜愛！\n很抱歉造成您的困擾，也很謝謝您的包容體諒。\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcebd'), 'name': '金冬天', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '平常沒有在寫評價，但這間的服務態度真的太好了，兩次去剛好都碰到人比較多的假日，但能感受到服務人員依舊非常細心，而且態度和藹可親。\n\n第一次用餐的時候因為不知道怎麼點 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcebe'), 'name': '陳素蕊', 'star': '5 顆星', 'comment_time': '6 個月前', 'comment': '炸雞口味多種選擇，肉很嫩多汁，下次會在回購', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~\n期待您再次蒞臨❤️❤️❤️'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcebf'), 'name': '楊楊楊', 'star': '5 顆星', 'comment_time': '1 個月前', 'comment': '好吃又親切 👍\n必須再光臨\U0001f970\U0001f970\U0001f970 …', 'store_comment': '無'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcec0'), 'name': 'Emily Kuo', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '好吃的韓式炸雞！開幕有點太低調，店裡只提供外送外帶，但服務很好！', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcec1'), 'name': 'Ai Ling Huang', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '今天下午五點多去取外帶，站櫃的短髮妹妹非常棒！帥氣貼心又有禮貌，以後外帶炸雞只會來林森店了！', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcec2'), 'name': 'Chia', 'star': '5 顆星', 'comment_time': '8 個月前', 'comment': '無內用區，外帶跟外送都如同預約時段，通常不需等待。服務、食物都沒問題，至於口味好吃與否就見仁見智。', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcec3'), 'name': 'Ross', 'star': '5 顆星', 'comment_time': '11 個月前', 'comment': '口味很讚 店員也都很親切會詳細介紹當月的活動，也會提醒食物會燙口很貼心\U0001f979 買起家雞來這間買就對了(⁎⁍̴̛ᴗ⁍̴̛⁎) …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcec4'), 'name': 'Sunshine', 'star': '4 顆星', 'comment_time': '1 年前', 'comment': '外送，口味還不錯。', 'store_comment': '感謝您的好評，歡迎再度光臨唷！\n我們會努力達到五顆星的！'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcec5'), 'name': 'Tsai Hachi', 'star': '1 顆星', 'comment_time': '1 年前', 'comment': '16:07打電話預約時被告知16:45可取餐\n16:30接到電話說已經可以取餐了\n準備出門加路上移動還有店內等候，實際取餐時間是16:57 …', 'store_comment': '很抱歉讓您有不佳的消費經驗，也很感謝您的回饋。\n我們會盡速審視工作流程並調整，在未來提供您更好的服務！'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcec6'), 'name': 'TZU', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '本來沒有習慣在評分的，但第二次去想嘗試其他種口味，店員推薦的哇樂炸雞很好吃！很特別的味道⋯雖然一開始吃到贈送的餅乾很不習慣，好像有中藥味。但實際吃熱騰騰的炸雞感覺非常不同！林森店出餐很準時迅速，短髮的店員很熱心介紹～好像梨泰院的女主角～好可愛！超級推薦南高雄的朋友可以來試試看！', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcec7'), 'name': '安', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '好吃的韓式炸雞～就是要起家雞～～', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcec8'), 'name': 'Jimy', 'star': '1 顆星', 'comment_time': '1 年前', 'comment': '12/31傍晚打電話要預訂，我十分能理解貴店在特殊節日生意一定好到忙不過來，但也不該在接到電話之後，跟我說了聲等一下，然後就把我晾在電話中晾了五分鐘，最後還直接把我的電話給掛了。\n如果真的太忙，說一句外帶已經額滿了就好，不用浪費彼此時間。', 'store_comment': '很抱歉讓您有不佳的消費經驗，也很感謝您的回饋。\n我們會盡速審視工作流程並調整，加強員工訓練努力做到最好！'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcec9'), 'name': '李汶岷', 'star': '4 顆星', 'comment_time': '1 年前', 'comment': '雞肉屬較濕潤口感，我比較愛乾的炸雞，但也不難吃，這是我個人喜好...', 'store_comment': '感謝您的好評，歡迎再度光臨唷！\n我們會努力達到五顆星的！'}
#
# {'_id': ObjectId('668f4d81919243eeb66bceca'), 'name': 'H', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '經過路過不要錯過，好吃的韓式炸雞。\n不管是一人用餐點雞翅、多人聚會點套餐都很適合，口味多樣選擇多。', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcecb'), 'name': 'ㄐㄇ', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '櫃檯人員態度親切，介紹餐點認真！\n炸雞也好吃～下次還會再來！！！', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcecc'), 'name': 'Ting Lee', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '炸雞非常好吃，韓式海苔飯糰也非常推推！\n服務人員非常細心也很熱情，而且態度和藹可親，下次還會再去☺️', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcecd'), 'name': '718012 s', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '櫃檯服務人員都很會推薦\n而且態度良好\n就算客人很多 還是會面帶笑容 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcece'), 'name': '關關', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '吃過三四種口味的炸雞，都很好吃！配醃蘿蔔很適合，年糕也很喜歡～', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcecf'), 'name': 'Ming Jung Chung', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '還是要說 這家的炸雞真的好吃 每個口味嘗過都覺得非常棒\n但是小點都有點不合我胃口就是了 有點可惜', 'store_comment': '感謝您的回饋！\n我們會加強不足的地方並在未來更好的服務您。'}
#
# {'_id': ObjectId('668f4d81919243eeb66bced0'), 'name': 'Zheng', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '去高雄玩時買過。味道不錯。服務人員都很親切 而且價格不貴 有機會還會再去', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bced1'), 'name': '陳聖丰', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '好吃的不行！\n每次經過都會買一點帶回去\n店家服務好，CP值超高\n不推不行\U0001f929 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bced2'), 'name': '阿豆', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '東西好吃跟一般炸雞比起來滿特別的～真的辛苦了今天還要上班的餐飲業人員了欸', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~  '}
#
# {'_id': ObjectId('668f4d81919243eeb66bced3'), 'name': 'junhyeokTW', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '坐在等待區看店員忙來忙去，單很多但很細心！炸雞熱熱的吃最好吃了！推薦～', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bced4'), 'name': '徐小桂', 'star': '5 顆星', 'comment_time': '11 個月前', 'comment': '服務人員態度超客氣～～\n餐點真的好好吃，每種都很推！！', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bced5'), 'name': 'Ming Chu', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '店長態度敬業 點餐還會詳細解說各口味的差異並推薦適合的口味 有夠貼心啦', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bced6'), 'name': '王立青', 'star': '5 顆星', 'comment_time': '10 個月前', 'comment': '今天去外帶有一個叫可晴的服務員很親切東西也用得很快速沒有等很久', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bced7'), 'name': '姚佳宏', 'star': '5 顆星', 'comment_time': '8 個月前', 'comment': '服務人員態度親切很有耐心，餐點也很好吃😋 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~❤️'}
#
# {'_id': ObjectId('668f4d81919243eeb66bced8'), 'name': '梁明寬', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '炸雞有多種口味可以選擇，很道地的口味，淋上青蔥醬的青蔥炸雞非常好吃😋 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bced9'), 'name': 'Pi Ying Ku', 'star': '5 顆星', 'comment_time': '8 個月前', 'comment': '炸雞多滋，可口美味，非常好吃，服務態度佳。', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~❤️'}
#
# {'_id': ObjectId('668f4d81919243eeb66bceda'), 'name': '陳妍熙', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '每個口味都好好吃，因為拿回家所以冷掉了，但不影響風味，一樣很美味。', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcedb'), 'name': 'Xiang', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '吃了店員推薦的青蔥，酸甜口味滿特別的\n上面的蔥絲也很多，跟家人吃得很開心~~~~', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcedc'), 'name': '吳繡杏', 'star': '5 顆星', 'comment_time': '6 個月前', 'comment': '超好吃！服務態度不錯👌 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~❤️'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcedd'), 'name': '林怡伶', 'star': '5 顆星', 'comment_time': '9 個月前', 'comment': '店員很親切 餐點很美味\n頂級洋釀真的好好吃🤤 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcede'), 'name': '小文', 'star': '5 顆星', 'comment_time': '8 個月前', 'comment': '真的好吃 想念韓國的洋釀醬時 就可以來這邊解饞了', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcedf'), 'name': '寵寵', 'star': '5 顆星', 'comment_time': '6 個月前', 'comment': '餐點很好吃😋\n會在回購 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~❤️'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcee0'), 'name': 'HAMBURGER Wang', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '沒吃過那麼好吃的韓式炸雞😋\n店員服務態度親切👍 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcee1'), 'name': 'YUI LIU', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '外帶回家還是很好吃💕無骨吃起來真的很方便～另外很愛他們家的年糕🤣🤣 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcee2'), 'name': '李孟臻', 'star': '4 顆星', 'comment_time': '1 年前', 'comment': '可以把「外送外帶店」打在標題嗎\n沒講誰知道==', 'store_comment': '很抱歉造成您的誤會，也很感謝您的回饋。\n門市類別可至Google資訊的「服務選項」確認，或到官網的「門市據點」查看喔~\n再次感謝您寶貴的意見，我們會加強不足的地方並在未來更好的服務您！'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcee3'), 'name': 'YiChun Liu', 'star': '5 顆星', 'comment_time': '10 個月前', 'comment': '服務人員態度很好，非常親切\n炸雞好吃😋 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcee4'), 'name': 'ann cat', 'star': '3 顆星', 'comment_time': '9 個月前', 'comment': '口味不錯，價位偏高，出餐迅速，選擇多樣', 'store_comment': '感謝您的回饋！\n也歡迎提出我們需要改進的地方，讓我們未來能更好的服務您。\n非常感謝您！'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcee5'), 'name': 'LI', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '餐點好吃 服務優質 推薦哇樂全雞～', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcee6'), 'name': 'LuLu Chen', 'star': '5 顆星', 'comment_time': '11 個月前', 'comment': '好吃', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcee7'), 'name': 'Ching', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '店員親切貼心\n會主動提醒可以搭配套餐👍🏻\n炸雞也好吃😋 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcee8'), 'name': 'Ya hui Chang (Chang)', 'star': '5 顆星', 'comment_time': '8 個月前', 'comment': '僅供外帶，但店員態度很好', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~❤️'}
#
# {'_id': ObjectId('668f4d81919243eeb66bcee9'), 'name': 'Laurence', 'star': '4 顆星', 'comment_time': '1 年前', 'comment': '好吃也很快速', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bceea'), 'name': 'Chun C.', 'star': '5 顆星', 'comment_time': '3 個月前', 'comment': '洋釀很特別很好吃', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~\n期待您再次蒞臨❤️❤️❤️'}
#
# {'_id': ObjectId('668f4d81919243eeb66bceeb'), 'name': 'Lion', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '洋釀雞跟小菜蘿蔔很好吃！\n店員茶米很親切❤️', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bceec'), 'name': '蔡宜真', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '好吃 店員也很熱情～ 會再回購！', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bceed'), 'name': 'Kunlin Xie', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '點餐出餐很有效率，現炸雞翅好好吃喔！', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bceee'), 'name': '古芷穎', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '婕瑜服務員態度很好，餐點好吃，已經來好幾次了', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d81919243eeb66bceef'), 'name': 'Ellen', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '店員服務態度很好\n介紹很仔細🉑️\n餐點也很好吃 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcef0'), 'name': 'QQ Chen', 'star': '5 顆星', 'comment_time': '11 個月前', 'comment': '短髮女員工好可愛，炸雞也好吃😍 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcef1'), 'name': '琳', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '原味，各種口味的炸雞都好吃，雞肉鮮嫩多汁，服務親切', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcef2'), 'name': '丁喜鈞', 'star': '4 顆星', 'comment_time': '1 年前', 'comment': '還是覺得原味搭配胡椒粉最對味！', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcef3'), 'name': '小草', 'star': '5 顆星', 'comment_time': '9 個月前', 'comment': '店員服務熱忱 動作快 食物又好吃😋 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcef4'), 'name': '台鐵拿鐵高鐵', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '今天 (2022/12/20)\n點的雞翅盒神好吃的  >///<\n(我是點哇樂)', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcef5'), 'name': '高羽涵', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '好好吃喔太喜歡了 女的帥 男的美', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcef6'), 'name': 'Chi Chen', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '好吃！可以另外購買醬，添增不同口味❤️', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~ '}
#
# {'_id': ObjectId('668f4d82919243eeb66bcef7'), 'name': '胡順博', 'star': '5 顆星', 'comment_time': '10 個月前', 'comment': '餐點很好吃 服務態度極佳', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcef8'), 'name': '金泓睿', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '服務人員態度親切\n東西好吃\n地瓜薯條讚', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~  '}
#
# {'_id': ObjectId('668f4d82919243eeb66bcef9'), 'name': '賴惠瑛', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '餐點好吃，服務人員親切接待', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcefa'), 'name': '蕭沛雯', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '好吃😋店員也很親切，推推👍 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcefb'), 'name': '蘇音綺', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '服務人員很親切～\n介紹菜單很仔細', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcefc'), 'name': '盧子勛', 'star': '5 顆星', 'comment_time': '9 個月前', 'comment': '店員很正\n炸雞也很正點', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcefd'), 'name': 'C.C', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '外帶，哇樂醬跟原味都好吃！', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcefe'), 'name': '禎禎', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '東西好吃😋服務人員態度好👌🏻 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bceff'), 'name': '陳婕瑜的瑜不是妤', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '服務人員態度親切\n去骨哇樂好吃', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf00'), 'name': 'D N', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '好吃，聚會餐點的最佳選擇👍 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf01'), 'name': '佳妏chen', 'star': '3 顆星', 'comment_time': '6 個月前', 'comment': '連鎖韓式炸雞店', 'store_comment': '感謝您的回饋！\n也歡迎提出我們需要改進的地方，讓我們未來能更好的服務您。\n我們會努力達到五顆星的，歡迎再度光臨唷！'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf02'), 'name': '옥수수諠', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '非常棒的體驗 餐點好ㄘ 讚！', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf03'), 'name': '林建燁', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '五星好評，我愛起家雞', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf04'), 'name': '劉以雯', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '韓式炸雞的第一首選 推推👍🏻 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf05'), 'name': 'TK Y', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '鮮嫩多汁，醬汁也好吃！', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf06'), 'name': 'M M', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '超愛起家雞，婕瑜服務很好👍 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf07'), 'name': 'Trista', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '服務好～餐點優！', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf08'), 'name': '郭大寶', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '服務極好 店員又帥又美 很細心\n👍👍👍👍👍 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf09'), 'name': 'Liu Amber', 'star': '4 顆星', 'comment_time': '1 年前', 'comment': '餐點好好吃、服務不錯', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf0a'), 'name': '蕭至凱', 'star': '5 顆星', 'comment_time': '1 個月前', 'comment': '好吃的炸雞👍 …', 'store_comment': '無'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf0b'), 'name': '張玄宇', 'star': '5 顆星', 'comment_time': '9 個月前', 'comment': '服務人員好看服務又好👍 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf0c'), 'name': 'Gattino', 'star': '3 顆星', 'comment_time': '9 個月前', 'comment': '推洋釀', 'store_comment': '感謝您的好評，歡迎再度光臨唷！\n我們會努力達到五顆星的！'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf0d'), 'name': '陳婕瑜', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '餐點好吃 服務人員親切', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf0e'), 'name': '洪聿榛', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '哇樂好吃😋\n辣味頂級好吃😋 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf0f'), 'name': 'Jimmy', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '東西好吃 服務好👍👍👍 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf10'), 'name': '胡咕嘰', 'star': '5 顆星', 'comment_time': '9 個月前', 'comment': '哇樂真的很值得一試', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf11'), 'name': 'CHRISTINE CHIANG', 'star': '5 顆星', 'comment_time': '3 個月前', 'comment': '炸雞美味😋 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~\n期待您再次蒞臨❤️❤️❤️'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf12'), 'name': 'Cynthia Yang', 'star': '5 顆星', 'comment_time': '10 個月前', 'comment': '店員態度很好👍 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf13'), 'name': '卓冠佑', 'star': '5 顆星', 'comment_time': '9 個月前', 'comment': '很好吃餒讚讚', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf14'), 'name': '莊少丞', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '餐點好吃 讚', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf15'), 'name': 'Cindy Chang', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '喝啤酒必配', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf16'), 'name': '鄭士靖', 'star': '1 顆星', 'comment_time': '1 年前', 'comment': '女員工態度差', 'store_comment': '很抱歉讓您有不佳的消費經驗，也很感謝您的回饋。\n我們會盡速審視工作流程並調整，在未來提供您更好的服務！'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf17'), 'name': 'Marina', 'star': '5 顆星', 'comment_time': '11 個月前', 'comment': '好吃', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf18'), 'name': 'zx zx', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '好吃很讚', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf19'), 'name': 'Richard Hsu', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '服務優良', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf1a'), 'name': 'Calla Yao', 'star': '4 顆星', 'comment_time': '1 年前', 'comment': '韓式炸雞店 最推', 'store_comment': '感謝您的好評，歡迎再度光臨唷！\n我們會努力達到五顆星的！'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf1b'), 'name': '林小姐', 'star': '5 顆星', 'comment_time': '9 個月前', 'comment': '東西好吃😋 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf1c'), 'name': '婕兒', 'star': '4 顆星', 'comment_time': '1 年前', 'comment': '很好吃', 'store_comment': '感謝您的好評，歡迎再度光臨唷！\n我們會努力達到五顆星的！'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf1d'), 'name': '윤혜주', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '好吃', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf1e'), 'name': '張珮禎', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '好吃好吃超好吃🤤 …', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf1f'), 'name': 'han ju Chuang', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '好吃好吃超好吃讚讚讚', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf20'), 'name': 'Gustavo M', 'star': '1 顆星', 'comment_time': '1 年前', 'comment': '好油膩', 'store_comment': '很抱歉讓您有不佳的消費經驗，也很感謝您的回饋。\n我們會盡速審視工作流程並調整，在未來提供您更好的服務！'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf21'), 'name': 'Kevin Sun (Hu)', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '好滑好嫩', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf22'), 'name': 'Yu Hsuan', 'star': '4 顆星', 'comment_time': '1 個月前', 'comment': '這是韓國炸雞店裡最便宜的。\n這是我的第二名', 'store_comment': '無'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf23'), 'name': 'YOON성운 (tongdark)', 'star': '3 顆星', 'comment_time': '2 個月前', 'comment': '味道就像90年代的韓國菜，雞肉又大又好吃。\n已經有一段時間沒有嚐到回憶的味道了', 'store_comment': '感謝您的點評並歡迎您的再次光臨！\n希望你常來台灣❤️'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf24'), 'name': '吳建謀', 'star': '5 顆星', 'comment_time': '10 個月前', 'comment': '好的', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf25'), 'name': 'claire', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf26'), 'name': '許紫琳', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf27'), 'name': '李品萱', 'star': '4 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '感謝您的好評，歡迎再度光臨唷！\n我們會努力達到五顆星的！'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf28'), 'name': 'Keno Yen (Keno)', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf29'), 'name': 'xiang', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf2a'), 'name': '洪小兔', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf2b'), 'name': 'james fan', 'star': '4 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '感謝您的好評，歡迎再度光臨唷！\n我們會努力達到五顆星的！'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf2c'), 'name': 'Yu Ting', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf2d'), 'name': 'Christopher Yen', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf2e'), 'name': '李芙蓉（fuzong）', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf2f'), 'name': 'Xuu', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf30'), 'name': 'Tim hsiao', 'star': '5 顆星', 'comment_time': '2 週前', 'comment': '無', 'store_comment': '無'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf31'), 'name': '陳宥希', 'star': '5 顆星', 'comment_time': '1 個月前', 'comment': '無', 'store_comment': '無'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf32'), 'name': '陳小戀', 'star': '5 顆星', 'comment_time': '1 個月前', 'comment': '無', 'store_comment': '無'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf33'), 'name': '醪醴', 'star': '5 顆星', 'comment_time': '1 個月前', 'comment': '無', 'store_comment': '無'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf34'), 'name': '傻柴', 'star': '5 顆星', 'comment_time': '1 個月前', 'comment': '無', 'store_comment': '無'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf35'), 'name': '張嘉升', 'star': '5 顆星', 'comment_time': '1 個月前', 'comment': '無', 'store_comment': '無'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf36'), 'name': '羅正武', 'star': '5 顆星', 'comment_time': '2 個月前', 'comment': '無', 'store_comment': '無'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf37'), 'name': 'Alice Shen', 'star': '4 顆星', 'comment_time': '2 個月前', 'comment': '無', 'store_comment': '感謝您的好評，歡迎再度光臨唷！\n我們會努力達到五顆星的！\n'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf38'), 'name': '高小龍', 'star': '4 顆星', 'comment_time': '3 個月前', 'comment': '無', 'store_comment': '無'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf39'), 'name': 'Karen', 'star': '5 顆星', 'comment_time': '3 個月前', 'comment': '無', 'store_comment': '無'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf3a'), 'name': '陳胖子', 'star': '3 顆星', 'comment_time': '3 個月前', 'comment': '無', 'store_comment': '感謝您的回饋！\n也歡迎提出我們需要改進的地方，讓我們未來能更好的服務您。\n期待您再次蒞臨❤️❤️❤️'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf3b'), 'name': '瀋炫', 'star': '5 顆星', 'comment_time': '4 個月前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~\n期待您再次蒞臨❤️❤️❤️'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf3c'), 'name': 'Yi-Ting Chen', 'star': '5 顆星', 'comment_time': '4 個月前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~\n期待您再次蒞臨❤️❤️❤️'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf3d'), 'name': '黃順通', 'star': '5 顆星', 'comment_time': '6 個月前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~❤️'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf3e'), 'name': '電機工程系李永泰', 'star': '5 顆星', 'comment_time': '6 個月前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~❤️'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf3f'), 'name': 'TT', 'star': '5 顆星', 'comment_time': '6 個月前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~❤️'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf40'), 'name': '徐珮慈', 'star': '5 顆星', 'comment_time': '6 個月前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~❤️'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf41'), 'name': 'Emelia Chen', 'star': '5 顆星', 'comment_time': '6 個月前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf42'), 'name': '劉惠珍', 'star': '5 顆星', 'comment_time': '7 個月前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~❤️'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf43'), 'name': '林璟郁', 'star': '5 顆星', 'comment_time': '8 個月前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~❤️'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf44'), 'name': 'ann tsai', 'star': '4 顆星', 'comment_time': '8 個月前', 'comment': '無', 'store_comment': '感謝您的好評，歡迎再度光臨唷！\n我們會努力達到五顆星的！'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf45'), 'name': '陳柏潤', 'star': '5 顆星', 'comment_time': '8 個月前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf46'), 'name': 'nianci liu', 'star': '5 顆星', 'comment_time': '9 個月前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf47'), 'name': '胡孝嫻', 'star': '5 顆星', 'comment_time': '9 個月前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf48'), 'name': '林林恩', 'star': '5 顆星', 'comment_time': '9 個月前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf49'), 'name': '龔阿真', 'star': '5 顆星', 'comment_time': '9 個月前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf4a'), 'name': '黃柏翰', 'star': '5 顆星', 'comment_time': '10 個月前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf4b'), 'name': '林彥廷', 'star': '5 顆星', 'comment_time': '10 個月前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf4c'), 'name': '海底喵', 'star': '5 顆星', 'comment_time': '10 個月前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf4d'), 'name': 'Claire Li', 'star': '5 顆星', 'comment_time': '10 個月前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf4e'), 'name': 'Eric', 'star': '5 顆星', 'comment_time': '10 個月前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf4f'), 'name': '洪雅婷', 'star': '5 顆星', 'comment_time': '10 個月前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf50'), 'name': '吳秀雯', 'star': '5 顆星', 'comment_time': '10 個月前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf51'), 'name': '千山', 'star': '5 顆星', 'comment_time': '11 個月前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf52'), 'name': '陳沛翎', 'star': '5 顆星', 'comment_time': '11 個月前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf53'), 'name': 'Eason Kuo', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf54'), 'name': '謝孟洲', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf55'), 'name': '吳雅筑', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf56'), 'name': 'lou麻雀', 'star': '4 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '感謝您的好評，歡迎再度光臨唷！\n我們會努力達到五顆星的！'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf57'), 'name': 'MAN', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf58'), 'name': '史威利', 'star': '4 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '感謝您的好評，歡迎再度光臨唷！\n我們會努力達到五顆星的！'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf59'), 'name': 'YING HSIEN YEH', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf5a'), 'name': 'Jocelyn Lee (李郁偵)', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf5b'), 'name': '陳紀', 'star': '1 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '很抱歉讓您有不佳的消費經驗，也很感謝您的回饋。\n也歡迎提出我們需要改進的地方，讓我們未來能更好的服務您。\n謝謝您！'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf5c'), 'name': '鄭人榕', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf5d'), 'name': '張凱翔', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf5e'), 'name': 'Yuchieh Lin', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf5f'), 'name': '動哇哈哈漫', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf60'), 'name': '楊佳螢', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf61'), 'name': '起家雞三多林森', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf62'), 'name': '林令儀', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf63'), 'name': 'ching Yi', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf64'), 'name': '洪睿辰', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf65'), 'name': '葉澤龍', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf66'), 'name': '方呈濬', 'star': '4 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '感謝您的好評，歡迎再度光臨唷！\n我們會努力達到五顆星的！'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf67'), 'name': '煌傑', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf68'), 'name': '森岡秀樹', 'star': '4 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '感謝您的好評，歡迎再度光臨唷！\n我們會努力達到五顆星的！'}
#
# {'_id': ObjectId('668f4d82919243eeb66bcf69'), 'name': '蘇蘇', 'star': '5 顆星', 'comment_time': '1 年前', 'comment': '無', 'store_comment': '感謝您的喜愛！\n要繼續支持起家雞唷~'}
